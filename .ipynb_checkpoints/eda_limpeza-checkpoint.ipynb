# %% [markdown]
# # Limpeza e Análise exploratória dos dados
#
# Este notebook tem como objetivo principal realizar a limpeza avançada e a Análise Exploratória de Dados (EDA) do dataset de telemetria de caminhões e escavadeiras. O foco do processo é a padronização das informações, remoção de ruídos operacionais e a construção da variável alvo (target) que será utilizada para modelagem preditiva, calculando o tempo restante até a próxima falha crítica (evento "Don't Go").
#
# Além disso, a partir desse ponto, o foco será analisar os dados provenientes da telemetria dos caminhões, uma vez que as escavadeiras geram pouquíssimos erros do tipo "Don't Go".
#
# ---

# %% [markdown]
# # Import dos dados e bibliotecas

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
from sklearn.feature_selection import mutual_info_classif

import unicodedata
import re
import pyarrow

# %%
df_caminhao = pd.read_parquet('datasets/datasets_tratados/df_caminhao_pre_processamento.parquet', engine="pyarrow")

# %% [markdown]
# # Avaliando erros e remoção de ruído

# %%
# Como a ideia é entender o comportamento de ativação dos erros, os alarmes do tipo "inactivate" não trariam informações que não ruído

filtro_classe = ~(df_caminhao['Classe'] == 'inactivate')
filtro_nome = ~(df_caminhao['Alarme'].str.contains('inactive'))

df_caminhao = df_caminhao[(filtro_classe) & (filtro_nome)]

# %%
# Função responsável por limpar o texto dos alarmes e da situação operacional
# removendo acentos e caracteres especiais e redundates e transformando em letras minusculas

def limpar_texto(texto):
    if not isinstance(texto, str):
        return ""

    # normalizacao unicode
    texto_normalizado = unicodedata.normalize('NFKD', texto)
    texto_limpo = "".join([c for c in texto_normalizado if not unicodedata.combining(c)])

    # lower
    texto_limpo = texto_limpo.lower()

    # substituindo caracteres especiais
    texto_limpo = re.sub(r'[^a-z0-9_]', '_', texto_limpo)

    # remove caracteres redundantes
    texto_limpo = re.sub(r'_+', '_', texto_limpo)

    # remove caracteres no inicio ou fim do texto
    texto_limpo = texto_limpo.strip('_')

    return texto_limpo

# Aplicando a limpeza nos dados
df_caminhao['Alarme'] = df_caminhao['Alarme'].apply(limpar_texto)
df_caminhao['Situacao_Operacional'] = df_caminhao['Situacao_Operacional'].apply(limpar_texto)

# %% [markdown]
# Após pesquisas, foram determinados que alguns dos alarmes gerados representam apenas ocorrências de funcionamento padrão dos equipamentos ou indicavam apenas erros de comunicação.
#
# Com base nas análises feitas, a remoção desses alarmes remove ruído dos dados e permite que os modelos de aprendizado de máquina possam entender realmente o comportamento dos erros que realmente prejudicam o equipamento.

# %%
alarmes_remover = [
    'dipper',
    'load',
    'cycle',
    'body_up',
    'rx_channel_a_not_receiving_messages',
    'rx_channel_b_not_receiving_messages',
    'oem_interface_timeout',
    'oem_interface_normal',

    # Esses alarmes foram cotados como possíveis alarmes ruidosos, mas foram mantidos
    # '1st_tire_tag_timeout',
    # '2nd_tire_tag_timeout',
    # '3rd_tire_tag_timeout',
    # '4th_tire_tag_timeout',
    # '5th_tire_tag_timeout',
    # '6th_tire_tag_timeout',
    ]

index_remover = df_caminhao[df_caminhao['Alarme'].isin(alarmes_remover)].index

df_caminhao = df_caminhao.drop(index_remover).reset_index(drop=True)

# %%
df_caminhao
# Out:
#                     Data_Evento  Dia      TAG Tag_Frota      Tipo  \
# 0       2025-01-01 00:00:48.100    1  CA65922  793-D 4S  Caminhao
# 1       2025-01-01 00:01:04.747    1  CA65925  793-D 4S  Caminhao
# 2       2025-01-01 00:01:04.747    1  CA65925  793-D 4S  Caminhao
# 3       2025-01-01 00:01:04.747    1  CA65925  793-D 4S  Caminhao
# 4       2025-01-01 00:01:04.747    1  CA65925  793-D 4S  Caminhao
# ...                         ...  ...      ...       ...       ...
# 1225232 2025-06-30 23:58:38.290   30  CA65921  793-D 4S  Caminhao
# 1225233 2025-06-30 23:58:56.647   30  CA65921  793-D 4S  Caminhao
# 1225234 2025-06-30 23:59:08.113   30  CA65926  793-D 4S  Caminhao
# 1225235 2025-06-30 23:59:41.847   30  CA65935  793-D 5S  Caminhao
# 1225236 2025-06-30 23:59:53.647   30  CA65935  793-D 5S  Caminhao
#
#         Nome_Operador_Anon                                Alarme  \
# 0                   OP_109               payload_overload_active
# 1                   OP_372                  4th_tire_tag_timeout
# 2                   OP_372                  3rd_tire_tag_timeout
# 3                   OP_372                  1st_tire_tag_timeout
# 4                   OP_372                  2nd_tire_tag_timeout
# ...                    ...                                   ...
# 1225232             OP_352            injector_cylinder_4_active
# 1225233             OP_352            injector_cylinder_4_active
# 1225234             OP_029  right_front_brake_temperature_active
# 1225235             OP_196                  5th_tire_tag_timeout
# 1225236             OP_196                  6th_tire_tag_timeout
#
#            Criticidade  Valor    Classe  Is_Dont_Go Situacao_Operacional  \
# 0        Informacional    2.0  Activate           0             operando
# 1        Informacional    0.0      NULL           0             operando
# 2        Informacional    0.0      NULL           0             operando
# 3        Informacional    0.0      NULL           0             operando
# 4        Informacional    0.0      NULL           0             operando
# ...                ...    ...       ...         ...                  ...
# 1225232    Não Crítico    2.0  Activate           0             operando
# 1225233    Não Crítico    2.0  Activate           0             operando
# 1225234        Crítico    2.0  Activate           1             operando
# 1225235  Informacional    0.0      NULL           0             operando
# 1225236  Informacional    0.0      NULL           0             operando
#
#               Turno  Tempo_Situacao  Tempo_Turno  Mes
# 0        Turno 18-6              48        21648    1
# 1        Turno 18-6              64        21664    1
# 2        Turno 18-6              64        21664    1
# 3        Turno 18-6              64        21664    1
# 4        Turno 18-6              64        21664    1
# ...             ...             ...          ...  ...
# 1225232  Turno 18-6            1868        21518    6
# 1225233  Turno 18-6            1886        21536    6
# 1225234  Turno 18-6            7644        21548    6
# 1225235  Turno 18-6             364        21581    6
# 1225236  Turno 18-6             376        21593    6
#
# [1225237 rows x 16 columns]

# %% [markdown]
# # Definindo target

# %% [markdown]
# O problema foi definido como uma classificação binária da ocorrências de erros do tipo "Don't Go" nas próximas 6 horas.
#
# Para isso, vamos inicialmente calcular quanto tempo falta até o próximo "Don't Go" com os dados agrupados por TAG e depois separamos esses valores em bins. A abordagem de calcular quanto tempo falta foi escolhida para que o problema facilmente pudesse ser transforamdo em uma regressão ou classificação multiclasse caso haja necessidade.

# %%
# Garantindo a ordenação correta dos dados
df_caminhao = df_caminhao.sort_values(by=['TAG', 'Data_Evento']).reset_index(
    drop=True
)

# Vetor que será usado para armazenar os minutos 
minutos_ate_falha = np.full(len(df_caminhao), np.nan)

# Iterando nos dados agrupados
for tag, group in df_caminhao.groupby('TAG'):
    indices_grupo = group.index

    # Datas onde Is_Dont_Go == 1
    datas_dont_go = group[group['Is_Dont_Go'] == 1]['Data_Evento'].values

    # Verificando máquinas sem falhas
    if len(datas_dont_go) == 0:
        continue

    # Evitando vazamento de dados, garantindo que sempre olhemos para o futuro
    momentos_busca = group['Data_Evento'] + pd.Timedelta(seconds=1)
    indices_busca = np.searchsorted(datas_dont_go, momentos_busca.values)

    # Procura por dados que não possuem pŕoximos erros
    sem_futuro = indices_busca >= len(datas_dont_go)
    indices_busca[sem_futuro] = len(datas_dont_go) - 1

    # Resgata a data do próximo Don't Go
    proximas_datas = datas_dont_go[indices_busca]

    # Calcula a diferença de tempo absoluta
    diferenca_tempo = proximas_datas - group['Data_Evento'].values

    # Converte a diferença de tempo para minutos (float)
    minutos = diferenca_tempo / np.timedelta64(1, 'm')

    minutos[sem_futuro] = np.nan

    minutos_ate_falha[indices_grupo] = minutos

# Adiciona a nova coluna na base
df_caminhao['Minutos_Ate_Proximo_Dont_Go'] = minutos_ate_falha

df_caminhao.dropna(subset=['Minutos_Ate_Proximo_Dont_Go'], inplace=True)

df_caminhao
# Out:
#                     Data_Evento  Dia      TAG Tag_Frota      Tipo  \
# 0       2025-01-01 00:24:02.000    1   CA5926  793-D 5S  Caminhao
# 1       2025-01-01 00:44:14.000    1   CA5926  793-D 5S  Caminhao
# 2       2025-01-01 01:32:44.000    1   CA5926  793-D 5S  Caminhao
# 3       2025-01-01 01:58:24.817    1   CA5926  793-D 5S  Caminhao
# 4       2025-01-01 02:15:07.817    1   CA5926  793-D 5S  Caminhao
# ...                         ...  ...      ...       ...       ...
# 1225197 2025-06-29 08:18:29.760   29  CA65937  793-D 5S  Caminhao
# 1225198 2025-06-29 09:02:26.847   29  CA65937  793-D 5S  Caminhao
# 1225199 2025-06-29 09:02:26.963   29  CA65937  793-D 5S  Caminhao
# 1225200 2025-06-29 09:24:18.230   29  CA65937  793-D 5S  Caminhao
# 1225201 2025-06-29 09:53:53.197   29  CA65937  793-D 5S  Caminhao
#
#         Nome_Operador_Anon                                  Alarme  \
# 0                   OP_261          mc_queda_pressao_do_oleo_motor
# 1                   OP_261          mc_queda_pressao_do_oleo_motor
# 2                   OP_261          mc_queda_pressao_do_oleo_motor
# 3                   OP_261                 payload_overload_active
# 4                   OP_261      left_rear_brake_temperature_active
# ...                    ...                                     ...
# 1225197             OP_258           transmission_oil_level_active
# 1225198             OP_258   right_rear_suspension_cylinder_active
# 1225199             OP_258  right_front_suspension_cylinder_active
# 1225200             OP_258                    parking_brake_active
# 1225201             OP_258   low_engine_coolant_temperature_active
#
#            Criticidade  Valor    Classe  Is_Dont_Go Situacao_Operacional  \
# 0              Crítico    NaN      NULL           0             operando
# 1              Crítico    NaN      NULL           0             operando
# 2              Crítico    NaN      NULL           0             operando
# 3        Informacional    2.0  Activate           0             operando
# 4              Crítico    2.0  Activate           0             operando
# ...                ...    ...       ...         ...                  ...
# 1225197        Crítico    3.0  Activate           1             operando
# 1225198    Não Crítico    2.0  Activate           0           manutencao
# 1225199    Não Crítico    2.0  Activate           0           manutencao
# 1225200        Crítico    2.0  Activate           0           manutencao
# 1225201  Informacional    1.0  Activate           0           manutencao
#
#               Turno  Tempo_Situacao  Tempo_Turno  Mes  \
# 0        Turno 18-6            1442        23042    1
# 1        Turno 18-6            2654        24254    1
# 2        Turno 18-6            1032        27164    1
# 3        Turno 18-6             288        28704    1
# 4        Turno 18-6            1291        29707    1
# ...             ...             ...          ...  ...
# 1225197  Turno 6-18            1316         8309    6
# 1225198  Turno 6-18            1278        10946    6
# 1225199  Turno 6-18            1278        10946    6
# 1225200  Turno 6-18            2590        12258    6
# 1225201  Turno 6-18            4365        14033    6
#
#          Minutos_Ate_Proximo_Dont_Go
# 0                        5703.772500
# 1                        5683.572500
# 2                        5635.072500
# 3                        5609.392217
# 4                        5592.675550
# ...                              ...
# 1225197                   103.430717
# 1225198                    59.479267
# 1225199                    59.477333
# 1225200                    37.622883
# 1225201                     8.040100
#
# [1203856 rows x 17 columns]

# %%
# Definindo os bins e criando a variável que será utilizada como target

bins = [0, 360, np.inf]
labels = ['0-6h', '6+']

df_caminhao['Classe_Risco'] = pd.cut(
    df_caminhao['Minutos_Ate_Proximo_Dont_Go'], 
    bins=bins, 
    labels=labels, 
    right=False
)

# %% [markdown]
# # Avaliando a distribuição dos erros

# %%
pd.crosstab(df_caminhao['TAG'], df_caminhao['Situacao_Operacional'])
# Out:
# Situacao_Operacional  hibernando  manutencao  operando  parado
# TAG
# CA5926                         0        3414     11599    1675
# CA5927                         0        1442      7009    1172
# CA65789                       49         386      3319     159
# CA65790                        0        4138     59142    7088
# CA65792                        0        5309     22971    2266
# CA65793                     1827        1555      2087     209
# CA65902                       21         388      3785     430
# CA65908                      452         969      6405     721
# CA65909                        0        5796     25478    4363
# CA65915                        0        4603     32923    4416
# CA65916                      485         131       254      35
# CA65921                        0        2012     27814    1648
# CA65922                        0        1578     16844    1531
# CA65923                       10        4465      8287    1742
# CA65924                        0       15356     87545   17020
# CA65925                        0       10044     58249   11578
# CA65926                        0        3803     11660    1789
# CA65927                        0        2419     29524    1500
# CA65928                        0        8206     92044    7307
# CA65929                        0        2134     17424    1491
# CA65930                        0        7809     68160    8662
# CA65931                        0        8424     46457    4953
# CA65932                        0        3588    115892    7115
# CA65933                        0        4210     14469    2433
# CA65934                        0        2906     39736    2611
# CA65935                        0        8009     45704    7141
# CA65936                        0       14716     87994   14542
# CA65937                        0        2366     10796    1668

# %%
pd.crosstab(df_caminhao['TAG'], df_caminhao['Is_Dont_Go'])
# Out:
# Is_Dont_Go       0     1
# TAG
# CA5926       16217   471
# CA5927        9153   470
# CA65789       3875    38
# CA65790      70304    64
# CA65792      28958  1588
# CA65793       5673     5
# CA65902       4207   417
# CA65908       7845   702
# CA65909      35409   228
# CA65915      41755   187
# CA65916        904     1
# CA65921      31275   199
# CA65922      19599   354
# CA65923      14271   233
# CA65924     119334   587
# CA65925      78957   914
# CA65926      12330  4922
# CA65927      32131  1312
# CA65928     106884   673
# CA65929      20830   219
# CA65930      83011  1620
# CA65931      58125  1709
# CA65932     126326   269
# CA65933      20537   575
# CA65934      44549   704
# CA65935      60523   331
# CA65936     117017   235
# CA65937      14091   739

# %%
pd.crosstab(df_caminhao['TAG'], df_caminhao['Criticidade'])
# Out:
# Criticidade  Crítico  Informacional  Não Crítico
# TAG
# CA5926          1478          10414         4796
# CA5927          2215           1948         5460
# CA65789          651           1527         1735
# CA65790         2465          63634         4269
# CA65792          484          12621        17441
# CA65793          183           4907          588
# CA65902          213            365         4046
# CA65908         4095            878         3574
# CA65909         1100          29429         5108
# CA65915         3286          34159         4497
# CA65916            4            684          217
# CA65921         1526           6723        23225
# CA65922         2074           2971        14908
# CA65923         2449           6064         5991
# CA65924         3326         103657        12938
# CA65925         2181          65937        11753
# CA65926         5501           3593         8158
# CA65927         2239           9096        22108
# CA65928        21977          63555        22025
# CA65929          856           7117        13076
# CA65930         3217          63039        18375
# CA65931         1956          40248        17630
# CA65932         1619         122089         2887
# CA65933         1434           9248        10430
# CA65934         1286           7640        36327
# CA65935          840          53596         6418
# CA65936         1023         106553         9676
# CA65937          911           3733        10186

# %% [markdown]
# A principio serão removidos os erros gerados por caminhões que só hibernaram durante todo o período dos dados estamos assumindo que esses erros não foram gerados durante a operação do equipamento e portanto não contribuirão para a modelagem
#
# Lista de tags a serem dropadas:
# - CA65791
# - CA65917

# %%
list_index = df_caminhao[df_caminhao['TAG'].isin(['CA65791', 'CA65917'])].index
df_caminhao.drop(list_index, inplace=True)

# %% [markdown]
# # Avaliando Séries dos Erros

# %%
def plot_serie_temporal_tag(tag_selecionada):

    df_tag = df_caminhao[df_caminhao['TAG'] == tag_selecionada].copy()

    # Garantimos que está ordenado por data
    df_tag = df_tag.sort_values(by='Data_Evento')

    # Contagem cumulativa contínua global
    df_tag['contagem_cumulativa'] = range(1, len(df_tag) + 1)

    # ==========================================
    # MAPEAMENTO DE CORES PARA OS STATUS
    # ==========================================
    # Ajuste os nomes das chaves de acordo com as strings exatas da sua coluna
    cores_status = {
        'operando': '#2ecc71',  # Verde
        'manutencao': '#3498db',  # Azul
        'parado': '#95a5a6',
        'hibernando': '#d3d3d3',  # Cinza
    }

    # ==========================================
    # 3. PLOTANDO O GRÁFICO SEPARADO POR MÊS
    # ==========================================
    sns.set_theme(style="whitegrid")

    # Criamos a grade separando pela coluna 'Mes'
    g = sns.FacetGrid(
        df_tag,
        col="Mes",
        col_wrap=3,
        sharex=False,
        sharey=False,  # Mantém o foco na faixa acumulada de cada mês
        height=4,
        aspect=1.3,
    )

    # Passo A: Linha mestre em degraus (esqueleto neutro do acúmulo)
    g.map_dataframe(
        sns.lineplot,
        x="Data_Evento",
        y="contagem_cumulativa",
        drawstyle='steps-pre',
        color='#bdc3c7',
        alpha=0.6,
        linewidth=1.5,
    )

    # Passo B: Função customizada para plotar as situações e os Don't Go
    def plot_detalhes_operacionais(data, **kwargs):
        if data.empty:
            return

        # 1. Plota todos os erros como pontinhos coloridos pelo status operacional atual
        # Usamos um tamanho controlado (s=25) para não sobrepor totalmente a linha
        # IMPORTANTE: Altere 'Situacao_Operacional' para o nome real da sua coluna de status
        sns.scatterplot(
            data=data,
            x="Data_Evento",
            y="contagem_cumulativa",
            hue="Situacao_Operacional",
            palette=cores_status,
            s=15,
            alpha=0.8,
            edgecolor=None,
            zorder=4,
        )

        # 2. Aplica o 'X' Vermelho Soberano exatamente onde houve o Don't Go
        df_critico = data[data['Is_Dont_Go'] == 1]
        if not df_critico.empty:
            plt.scatter(
                df_critico['Data_Evento'],
                df_critico['contagem_cumulativa'],
                color='red',
                marker='X',  # O 'X' destaca muito mais que uma bolinha
                s=50,  # Bem maior para sobressair no meio dos outros pontos
                zorder=5,
            )

    # Aplicando a nossa função lógica na grade
    g.map_dataframe(plot_detalhes_operacionais)

    # Ajustes de estética dos eixos
    g.set_axis_labels("Data do Evento", "Total de Alarmes Acumulados")
    g.set_titles(col_template="Mês: {col_name}")

    # Rotacionando as datas no eixo X para ficar legível
    for ax in g.axes.flat:
        for label in ax.get_xticklabels():
            label.set_rotation(45)

    # ==========================================
    # CRIAÇÃO DA LEGENDA MANUAL GLOBAL
    # ==========================================
    # Construímos a legenda do zero para evitar duplicações e bugs de mapeamento do FacetGrid
    legend_elements = [
        mlines.Line2D(
            [0],
            [0],
            color='#bdc3c7',
            linewidth=2,
            label='Tendência Global de Alarmes',
        ),
        mlines.Line2D(
            [0],
            [0],
            marker='o',
            color='w',
            markerfacecolor='#2ecc71',
            markersize=8,
            label='Status: Operação',
        ),
        mlines.Line2D(
            [0],
            [0],
            marker='o',
            color='w',
            markerfacecolor='#3498db',
            markersize=8,
            label='Status: Manutenção',
        ),mlines.Line2D(
            [0],
            [0],
            marker='o',
            color='w',
            markerfacecolor='#95a5a6',
            markersize=8,
            label='Status: Parado',
        ),
        mlines.Line2D(
            [0],
            [0],
            marker='o',
            color='w',
            markerfacecolor='#d3d3d3',
            markersize=8,
            label='Status: Hibernando',
        ),
        mlines.Line2D(
            [0],
            [0],
            marker='X',
            color='w',
            markerfacecolor='red',
            markeredgecolor='red',
            markersize=9,
            label="Evento 'Don't Go'",
        ),
    ]

    # Joga a legenda para fora dos gráficos, centralizada à direita
    g.fig.legend(
        handles=legend_elements,
        loc='center left',
        bbox_to_anchor=(1.01, 0.5),
        title="Dicionário de Eventos",
    )

    plt.suptitle(
        f"Análise de Alarmes por Estado Operacional - Equipamento: {tag_selecionada}",
        y=1.05,
        fontsize=16,
    )

    # Ajusta o layout deixando uma margem na direita (rect) para a legenda não ser cortada
    plt.tight_layout(rect=[0, 0, 0.9, 1])
    plt.show()

# %%
tags = df_caminhao['TAG'].unique()

for tag in tags:
    plot_serie_temporal_tag(tag)

# %%
crosstab_alarme_criticidade = pd.crosstab(
    df_caminhao['Alarme'],
    df_caminhao['Criticidade']
)

crosstab_alarme_criticidade
# Out:
# Criticidade                                Crítico  Informacional  Não Crítico
# Alarme
# 1st_tire_pressure_high_maximum                   0              9            0
# 1st_tire_pressure_low                            0           1172            0
# 1st_tire_pressure_low_minimum                  272           1374            4
# 1st_tire_pressure_very_low                     267              0            0
# 1st_tire_tag_high_pressure_change_rate           0           1091            0
# ...                                            ...            ...          ...
# vims_event_list_active                           0             65           47
# vims_main_ecm_active                             0              0         1941
# vims_road_analysis_control_rac_ecm_active        0              0           12
# vims_snapshot_active                             0            127           87
# vims_transmission_ecm_active                     0              0          222
#
# [214 rows x 3 columns]

# %% [markdown]
# # Distribuição de erros do tipo Don't Go

# %%
df_caminhao
# Out:
#                     Data_Evento  Dia      TAG Tag_Frota      Tipo  \
# 0       2025-01-01 00:24:02.000    1   CA5926  793-D 5S  Caminhao
# 1       2025-01-01 00:44:14.000    1   CA5926  793-D 5S  Caminhao
# 2       2025-01-01 01:32:44.000    1   CA5926  793-D 5S  Caminhao
# 3       2025-01-01 01:58:24.817    1   CA5926  793-D 5S  Caminhao
# 4       2025-01-01 02:15:07.817    1   CA5926  793-D 5S  Caminhao
# ...                         ...  ...      ...       ...       ...
# 1225197 2025-06-29 08:18:29.760   29  CA65937  793-D 5S  Caminhao
# 1225198 2025-06-29 09:02:26.847   29  CA65937  793-D 5S  Caminhao
# 1225199 2025-06-29 09:02:26.963   29  CA65937  793-D 5S  Caminhao
# 1225200 2025-06-29 09:24:18.230   29  CA65937  793-D 5S  Caminhao
# 1225201 2025-06-29 09:53:53.197   29  CA65937  793-D 5S  Caminhao
#
#         Nome_Operador_Anon                                  Alarme  \
# 0                   OP_261          mc_queda_pressao_do_oleo_motor
# 1                   OP_261          mc_queda_pressao_do_oleo_motor
# 2                   OP_261          mc_queda_pressao_do_oleo_motor
# 3                   OP_261                 payload_overload_active
# 4                   OP_261      left_rear_brake_temperature_active
# ...                    ...                                     ...
# 1225197             OP_258           transmission_oil_level_active
# 1225198             OP_258   right_rear_suspension_cylinder_active
# 1225199             OP_258  right_front_suspension_cylinder_active
# 1225200             OP_258                    parking_brake_active
# 1225201             OP_258   low_engine_coolant_temperature_active
#
#            Criticidade  Valor    Classe  Is_Dont_Go Situacao_Operacional  \
# 0              Crítico    NaN      NULL           0             operando
# 1              Crítico    NaN      NULL           0             operando
# 2              Crítico    NaN      NULL           0             operando
# 3        Informacional    2.0  Activate           0             operando
# 4              Crítico    2.0  Activate           0             operando
# ...                ...    ...       ...         ...                  ...
# 1225197        Crítico    3.0  Activate           1             operando
# 1225198    Não Crítico    2.0  Activate           0           manutencao
# 1225199    Não Crítico    2.0  Activate           0           manutencao
# 1225200        Crítico    2.0  Activate           0           manutencao
# 1225201  Informacional    1.0  Activate           0           manutencao
#
#               Turno  Tempo_Situacao  Tempo_Turno  Mes  \
# 0        Turno 18-6            1442        23042    1
# 1        Turno 18-6            2654        24254    1
# 2        Turno 18-6            1032        27164    1
# 3        Turno 18-6             288        28704    1
# 4        Turno 18-6            1291        29707    1
# ...             ...             ...          ...  ...
# 1225197  Turno 6-18            1316         8309    6
# 1225198  Turno 6-18            1278        10946    6
# 1225199  Turno 6-18            1278        10946    6
# 1225200  Turno 6-18            2590        12258    6
# 1225201  Turno 6-18            4365        14033    6
#
#          Minutos_Ate_Proximo_Dont_Go Classe_Risco
# 0                        5703.772500           6+
# 1                        5683.572500           6+
# 2                        5635.072500           6+
# 3                        5609.392217           6+
# 4                        5592.675550           6+
# ...                              ...          ...
# 1225197                   103.430717         0-6h
# 1225198                    59.479267         0-6h
# 1225199                    59.477333         0-6h
# 1225200                    37.622883         0-6h
# 1225201                     8.040100         0-6h
#
# [1203856 rows x 18 columns]

# %%
# ==========================================
# 1. FILTRANDO APENAS OS EVENTOS 'DON'T GO'
# ==========================================
# Criamos um DataFrame contendo apenas as linhas onde o Don't Go aconteceu
df_dont_go_apenas = df_caminhao[df_caminhao['Is_Dont_Go'] == 1].copy()

# ==========================================
# 2. CONFIGURANDO E PLOTANDO O GRÁFICO
# ==========================================
sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 6))

# Criamos o gráfico de barras
# IMPORTANTE: Substitua 'Situacao_Operacional' pelo nome exato da sua coluna
ax = sns.countplot(
    data=df_dont_go_apenas,
    x='Situacao_Operacional',
    hue='Situacao_Operacional',
    edgecolor="black",
    linewidth=1
)

# Adicionando os valores exatos (rótulos) no topo de cada barra para facilitar a leitura
for p in ax.patches:
    height = p.get_height()
    ax.annotate(
        f'{int(height):,}',  # Formata com separador de milhar
        (p.get_x() + p.get_width() / 2., height),
        ha='center', 
        va='bottom', 
        fontsize=11, 
        fontweight='bold',
        xytext=(0, 5), 
        textcoords='offset points'
    )

# Ajustes de títulos e eixos
plt.title("Distribuição de Eventos 'Don't Go' por Situação Operacional", fontsize=15, pad=15, fontweight='bold')
plt.xlabel("Situação Operacional do Equipamento", fontsize=12)
plt.ylabel("Quantidade Total de Erros 'Don't Go'", fontsize=12)

# Ajusta margens para não cortar textos
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Configurando o estilo visual do Seaborn
sns.set_theme(style="whitegrid")

# Criando a área para 2 gráficos lado a lado
fig, axes = plt.subplots(1, 2, figsize=(18, 6))

# =====================================================================
# GRÁFICO 1: Top 15 Operadores com Mais 'Don't Go' (Absoluto)
# =====================================================================
df_dont_go = df_caminhao[df_caminhao['Is_Dont_Go'] == 1]

# Agrupamos e pegamos os 15 que mais aparecem
top_operadores_abs = df_dont_go["Nome_Operador_Anon"].value_counts().head(15).reset_index()
top_operadores_abs.columns = ["Nome_Operador_Anon", 'Quantidade_Dont_Go']

sns.barplot(
    data=top_operadores_abs,
    y="Nome_Operador_Anon",
    x='Quantidade_Dont_Go',
    palette="Reds_r", # Cores degradê vermelhas para destacar o topo
    ax=axes[0],
    edgecolor="black"
)

axes[0].set_title("Top 15 Operadores com Maior Volume Absoluto de 'Don't Go'", fontsize=13, fontweight='bold')
axes[0].set_xlabel("Quantidade Total de Eventos 'Don't Go'")
axes[0].set_ylabel("Identificação do Operador")

# Adiciona os valores no fim de cada barra
for p in axes[0].patches:
    width = p.get_width()
    axes[0].annotate(
        f'{int(width):,}',
        (width, p.get_y() + p.get_height() / 2.),
        ha='left', 
        va='center', 
        xytext=(5, 0), 
        textcoords='offset points',
        fontsize=10
    )

# =====================================================================
# GRÁFICO 2: Top 15 Operadores por Taxa de 'Don't Go' (Proporcional)
# =====================================================================
# Para evitar operadores que trabalharam apenas 5 minutos e tiveram 1 erro (taxa de 100%),
# filtramos apenas operadores que geraram um volume mínimo de logs gerais (ex: pelo menos 500 erros)
minimo_logs = 500
contagem_geral = df_caminhao["Nome_Operador_Anon"].value_counts()
operadores_frequentes = contagem_geral[contagem_geral >= minimo_logs].index

df_filtrado_op = df_caminhao[df_caminhao["Nome_Operador_Anon"].isin(operadores_frequentes)]

# Calculamos a taxa: (soma de dont_go / total de logs) * 100
taxa_operador = (
    df_filtrado_op.groupby("Nome_Operador_Anon")['Is_Dont_Go']
    .mean() * 100
).reset_index()

taxa_operador.columns = ["Nome_Operador_Anon", 'Taxa_Dont_Go_Percentual']
top_operadores_taxa = taxa_operador.sort_values(by='Taxa_Dont_Go_Percentual', ascending=False).head(15)

sns.barplot(
    data=top_operadores_taxa,
    y="Nome_Operador_Anon",
    x='Taxa_Dont_Go_Percentual',
    palette="Oranges_r",
    ax=axes[1],
    edgecolor="black"
)

axes[1].set_title(f"Top 15 por Taxa de 'Don't Go' (mínimo {minimo_logs} logs gerados)", fontsize=13, fontweight='bold')
axes[1].set_xlabel("Taxa de Erros que viram 'Don't Go' (%)")
axes[1].set_ylabel("") # Remove para não repetir o rótulo do eixo Y

# Adiciona as porcentagens no fim de cada barra
for p in axes[1].patches:
    width = p.get_width()
    axes[1].annotate(
        f'{width:.2f}%',
        (width, p.get_y() + p.get_height() / 2.),
        ha='left', 
        va='center', 
        xytext=(5, 0), 
        textcoords='offset points',
        fontsize=10
    )

# Título Geral
plt.suptitle("Análise de Influência do Fator Humano nos Eventos de Falha", y=1.02, fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_29555/989152153.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# /tmp/ipykernel_29555/989152153.py:67: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Configurando o estilo visual do Seaborn
sns.set_theme(style="whitegrid")

# Criando a área do gráfico com 2 subplots lado a lado
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Filtramos os valores nulos para não dar erro no plot
dados_plot = df_caminhao['Minutos_Ate_Proximo_Dont_Go'].dropna()

# Convertendo para horas para facilitar a interpretação operacional
horas_ate_falha = dados_plot / 60

# =====================================================================
# GRAFICO 1: Distribuição Total (Visão Geral)
# =====================================================================
sns.histplot(
    horas_ate_falha,
    bins=50,
    kde=True,
    color='#34495e',
    ax=axes[0]
)
axes[0].set_title("Distribuição Completa (em Horas)", fontsize=13, fontweight='bold')
axes[0].set_xlabel("Tempo até o próximo Don't Go (Horas)")
axes[0].set_ylabel("Frequência (Quantidade de Logs)")

# =====================================================================
# GRAFICO 2: Zoom nas primeiras 48 horas (Foco na Degradação Ativa)
# =====================================================================
# Filtramos apenas eventos que acontecem em até 48 horas (2880 minutos)
horas_limite = 48
dados_zoom = horas_ate_falha[horas_ate_falha <= horas_limite]

sns.histplot(
    dados_zoom,
    bins=48, # 1 bin por hora para ficar bem detalhado
    kde=True,
    color='#e74c3c', # Vermelho para destacar a zona crítica
    ax=axes[1]
)
# Adiciona linhas de referência para ajudar na tomada de decisão operacional
axes[1].axvline(x=6, color='black', linestyle='--', alpha=0.7, label='Janela de 6h')
axes[1].axvline(x=12, color='blue', linestyle='--', alpha=0.7, label='Janela de 12h')

axes[1].set_title(f"Foco nas Primeiras {horas_limite} Horas (Zona de Risco)", fontsize=13, fontweight='bold')
axes[1].set_xlabel("Tempo até o próximo Don't Go (Horas)")
axes[1].set_ylabel("Frequência (Quantidade de Logs)")
axes[1].legend()

# Título Geral do Painel
plt.suptitle("Análise de Dispersão: Tempo Restante até o Próximo Evento 'Don't Go'", y=1.02, fontsize=16, fontweight='bold')

plt.tight_layout()
plt.show()

# %%
df_caminhao['Criticidade'].unique()
# Out:
# <ArrowStringArray>
# ['Crítico', 'Informacional', 'Não Crítico']
# Length: 3, dtype: str

# %% [markdown]
# # Salvando os dados limpos

# %%
# Salvando datasets filtrados
df_caminhao.to_parquet('datasets/datasets_tratados/df_caminhao_limpo.parquet', engine='pyarrow')
